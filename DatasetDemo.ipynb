# %%
import pandas
import data_process
data  = pandas.read_csv('./motionClassify.csv')

# %%
dataset = data_process.gen_dataset(data)

# %%
dataset[654]
# Out:
# (tensor([17866,  5371,    24,   191,  1743,   374,  1807,  3465,  2172,  5604,
#           1021,  1141,    23,    18,   323, 29800,  3483,  2741,   327,    33,
#            107,  5415,    94,  1579,  2860,   545, 10926,    58,    40, 85023,
#           6835,   106, 10788,  8655, 11721,   117,   128,  8197,   514,  7223,
#           9393,  4354,  4033, 26864,  1905,  1823,   567,   456, 17414, 29956,
#             38,  7213,     9, 14021,   116,   714,  5203,  1358,   854,   254,
#            388,   456,   136, 14839, 15888,    53,     1,    80,     4,  5415,
#            316,     2,  3829,   466,  3379,  1806,  1926,   177,    10,  1579,
#            120,  1601,   120,    64, 15889,    21,   959,  2199,  5340,   115,
#            244,  5021,  5981, 14281,     1,    15,    38,   104,  4973,  5142,
#           1002,  1046,   120,  3676,   236, 10927,   106,  1404,  9393,    54,
#          22031,    65,  1334,    27,    54,  1003,   126,    54,  2741,   327,
# ...
